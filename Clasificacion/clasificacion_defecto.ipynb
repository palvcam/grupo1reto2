# %%
import cv2
import numpy as np
from pathlib import Path
import shutil

# =========================
# RUTAS
# =========================
INPUT_DIR = Path("../Imagenes_defectos")        # carpeta original
OUTPUT_DIR = Path("data_imagenes/clasificados")

DEFECT_DIR = OUTPUT_DIR / "defecto"
OK_DIR = OUTPUT_DIR / "no_defecto"

DEFECT_DIR.mkdir(parents=True, exist_ok=True)
OK_DIR.mkdir(parents=True, exist_ok=True)

# =========================
# PARÁMETROS DE DECISIÓN
# =========================
WHITE_THRESHOLD = 10     # para considerar un píxel "blanco"
MIN_WHITE_PIXELS = 1     # con que haya 1 píxel blanco ya es defecto

# =========================
# FUNCIÓN: decidir defecto
# =========================
def is_defective(mask_path):
    mask = cv2.imread(str(mask_path), cv2.IMREAD_GRAYSCALE)
    if mask is None:
        return False

    white_pixels = np.sum(mask > WHITE_THRESHOLD)
    return white_pixels >= MIN_WHITE_PIXELS

# =========================
# PROCESO PRINCIPAL
# =========================
total = 0
defect_count = 0
ok_count = 0

for kos_dir in INPUT_DIR.iterdir():
    if not kos_dir.is_dir():
        continue

    kos_name = kos_dir.name
    print(f"\nProcesando {kos_name}")

    for img_path in kos_dir.glob("Part*.jpg"):

        mask_path = img_path.with_name(img_path.stem + "_label.bmp")

        if not mask_path.exists():
            print(f" Falta máscara para {img_path.name}")
            continue

        if is_defective(mask_path):
            target_dir = DEFECT_DIR
            defect_count += 1
            label = "DEFECTO"
        else:
            target_dir = OK_DIR
            ok_count += 1
            label = "NO_DEFECTO"

        # nombre único para evitar colisiones
        new_name = f"{kos_name}_{img_path.name}"

        shutil.copy(img_path, target_dir / new_name)
        total += 1

        print(f"  {label}: {new_name}")

# =========================
# RESUMEN
# =========================
print("\n===== RESUMEN FINAL =====")
print(f"Total imágenes procesadas: {total}")
print(f"Defecto: {defect_count}")
print(f"No defecto: {ok_count}")
# Out:
# Procesando kos01
#   NO_DEFECTO: kos01_Part0.jpg
#   NO_DEFECTO: kos01_Part1.jpg
#   NO_DEFECTO: kos01_Part2.jpg
#   NO_DEFECTO: kos01_Part3.jpg
#   NO_DEFECTO: kos01_Part4.jpg
#   DEFECTO: kos01_Part5.jpg
#   NO_DEFECTO: kos01_Part6.jpg
#   NO_DEFECTO: kos01_Part7.jpg
#
# Procesando kos02
#   NO_DEFECTO: kos02_Part0.jpg
#   NO_DEFECTO: kos02_Part1.jpg
#   NO_DEFECTO: kos02_Part2.jpg
#   NO_DEFECTO: kos02_Part3.jpg
#   NO_DEFECTO: kos02_Part4.jpg
#   NO_DEFECTO: kos02_Part5.jpg
#   DEFECTO: kos02_Part6.jpg
#   NO_DEFECTO: kos02_Part7.jpg
#
# Procesando kos03
#   NO_DEFECTO: kos03_Part0.jpg
#   NO_DEFECTO: kos03_Part1.jpg
#   DEFECTO: kos03_Part2.jpg
#   NO_DEFECTO: kos03_Part3.jpg
#   NO_DEFECTO: kos03_Part4.jpg
#   NO_DEFECTO: kos03_Part5.jpg
#   NO_DEFECTO: kos03_Part6.jpg
#   NO_DEFECTO: kos03_Part7.jpg
#
# Procesando kos04
#   NO_DEFECTO: kos04_Part0.jpg
#   NO_DEFECTO: kos04_Part1.jpg
#   NO_DEFECTO: kos04_Part2.jpg
#   DEFECTO: kos04_Part3.jpg
#   NO_DEFECTO: kos04_Part4.jpg
#   NO_DEFECTO: kos04_Part5.jpg
#   NO_DEFECTO: kos04_Part6.jpg
#   NO_DEFECTO: kos04_Part7.jpg
#
# Procesando kos05
#   NO_DEFECTO: kos05_Part0.jpg
#   NO_DEFECTO: kos05_Part1.jpg
#   NO_DEFECTO: kos05_Part2.jpg
#   NO_DEFECTO: kos05_Part3.jpg
#   NO_DEFECTO: kos05_Part4.jpg
#   DEFECTO: kos05_Part5.jpg
#   NO_DEFECTO: kos05_Part6.jpg
#   NO_DEFECTO: kos05_Part7.jpg
#
# Procesando kos06
#   NO_DEFECTO: kos06_Part0.jpg
#   NO_DEFECTO: kos06_Part1.jpg
#   NO_DEFECTO: kos06_Part2.jpg
#   NO_DEFECTO: kos06_Part3.jpg
#   NO_DEFECTO: kos06_Part4.jpg
#   NO_DEFECTO: kos06_Part5.jpg
#   NO_DEFECTO: kos06_Part6.jpg
#   DEFECTO: kos06_Part7.jpg
#
# Procesando kos07
#   NO_DEFECTO: kos07_Part0.jpg
#   DEFECTO: kos07_Part1.jpg
#   NO_DEFECTO: kos07_Part2.jpg
#   NO_DEFECTO: kos07_Part3.jpg
#   NO_DEFECTO: kos07_Part4.jpg
#   NO_DEFECTO: kos07_Part5.jpg
#   NO_DEFECTO: kos07_Part6.jpg
#   NO_DEFECTO: kos07_Part7.jpg
#
# Procesando kos08
#   NO_DEFECTO: kos08_Part0.jpg
#   NO_DEFECTO: kos08_Part1.jpg
#   DEFECTO: kos08_Part2.jpg
#   NO_DEFECTO: kos08_Part3.jpg
#   NO_DEFECTO: kos08_Part4.jpg
#   NO_DEFECTO: kos08_Part5.jpg
#   NO_DEFECTO: kos08_Part6.jpg
#   NO_DEFECTO: kos08_Part7.jpg
#
# Procesando kos09
#   NO_DEFECTO: kos09_Part0.jpg
#   NO_DEFECTO: kos09_Part1.jpg
#   NO_DEFECTO: kos09_Part2.jpg
#   NO_DEFECTO: kos09_Part3.jpg
#   NO_DEFECTO: kos09_Part4.jpg
#   NO_DEFECTO: kos09_Part5.jpg
#   DEFECTO: kos09_Part6.jpg
#   NO_DEFECTO: kos09_Part7.jpg
#
# Procesando kos10
#   NO_DEFECTO: kos10_Part0.jpg
#   NO_DEFECTO: kos10_Part1.jpg
#   NO_DEFECTO: kos10_Part2.jpg
#   DEFECTO: kos10_Part3.jpg
#   NO_DEFECTO: kos10_Part4.jpg
#   NO_DEFECTO: kos10_Part5.jpg
#   NO_DEFECTO: kos10_Part6.jpg
#   NO_DEFECTO: kos10_Part7.jpg
#
# Procesando kos11
#   NO_DEFECTO: kos11_Part0.jpg
#   NO_DEFECTO: kos11_Part1.jpg
#   NO_DEFECTO: kos11_Part2.jpg
#   NO_DEFECTO: kos11_Part3.jpg
#   DEFECTO: kos11_Part4.jpg
#   NO_DEFECTO: kos11_Part5.jpg
#   NO_DEFECTO: kos11_Part6.jpg
#   NO_DEFECTO: kos11_Part7.jpg
#
# Procesando kos12
#   NO_DEFECTO: kos12_Part0.jpg
#   NO_DEFECTO: kos12_Part1.jpg
#   NO_DEFECTO: kos12_Part2.jpg
#   NO_DEFECTO: kos12_Part3.jpg
#   NO_DEFECTO: kos12_Part4.jpg
#   DEFECTO: kos12_Part5.jpg
#   NO_DEFECTO: kos12_Part6.jpg
#   NO_DEFECTO: kos12_Part7.jpg
#
# Procesando kos13
#   NO_DEFECTO: kos13_Part0.jpg
#   NO_DEFECTO: kos13_Part1.jpg
#   NO_DEFECTO: kos13_Part2.jpg
#   DEFECTO: kos13_Part3.jpg
#   NO_DEFECTO: kos13_Part4.jpg
#   NO_DEFECTO: kos13_Part5.jpg
#   NO_DEFECTO: kos13_Part6.jpg
#   NO_DEFECTO: kos13_Part7.jpg
#
# Procesando kos14
#   NO_DEFECTO: kos14_Part0.jpg
#   NO_DEFECTO: kos14_Part1.jpg
#   NO_DEFECTO: kos14_Part2.jpg
#   NO_DEFECTO: kos14_Part3.jpg
#   NO_DEFECTO: kos14_Part4.jpg
#   NO_DEFECTO: kos14_Part5.jpg
#   NO_DEFECTO: kos14_Part6.jpg
#   DEFECTO: kos14_Part7.jpg
#
# Procesando kos15
#   NO_DEFECTO: kos15_Part0.jpg
#   NO_DEFECTO: kos15_Part1.jpg
#   NO_DEFECTO: kos15_Part2.jpg
#   DEFECTO: kos15_Part3.jpg
#   NO_DEFECTO: kos15_Part4.jpg
#   NO_DEFECTO: kos15_Part5.jpg
#   NO_DEFECTO: kos15_Part6.jpg
#   NO_DEFECTO: kos15_Part7.jpg
#
# Procesando kos16
#   NO_DEFECTO: kos16_Part0.jpg
#   NO_DEFECTO: kos16_Part1.jpg
#   NO_DEFECTO: kos16_Part2.jpg
#   NO_DEFECTO: kos16_Part3.jpg
#   NO_DEFECTO: kos16_Part4.jpg
#   DEFECTO: kos16_Part5.jpg
#   NO_DEFECTO: kos16_Part6.jpg
#   NO_DEFECTO: kos16_Part7.jpg
#
# Procesando kos17
#   NO_DEFECTO: kos17_Part0.jpg
#   NO_DEFECTO: kos17_Part1.jpg
#   NO_DEFECTO: kos17_Part2.jpg
#   NO_DEFECTO: kos17_Part3.jpg
#   NO_DEFECTO: kos17_Part4.jpg
#   DEFECTO: kos17_Part5.jpg
#   NO_DEFECTO: kos17_Part6.jpg
#   NO_DEFECTO: kos17_Part7.jpg
#
# Procesando kos18
#   NO_DEFECTO: kos18_Part0.jpg
#   NO_DEFECTO: kos18_Part1.jpg
#   NO_DEFECTO: kos18_Part2.jpg
#   DEFECTO: kos18_Part3.jpg
#   NO_DEFECTO: kos18_Part4.jpg
#   NO_DEFECTO: kos18_Part5.jpg
#   NO_DEFECTO: kos18_Part6.jpg
#   NO_DEFECTO: kos18_Part7.jpg
#
# Procesando kos19
#   NO_DEFECTO: kos19_Part0.jpg
#   NO_DEFECTO: kos19_Part1.jpg
#   NO_DEFECTO: kos19_Part2.jpg
#   NO_DEFECTO: kos19_Part3.jpg
#   NO_DEFECTO: kos19_Part4.jpg
#   DEFECTO: kos19_Part5.jpg
#   NO_DEFECTO: kos19_Part6.jpg
#   NO_DEFECTO: kos19_Part7.jpg
#
# Procesando kos20
#   NO_DEFECTO: kos20_Part0.jpg
#   NO_DEFECTO: kos20_Part1.jpg
#   NO_DEFECTO: kos20_Part2.jpg
#   NO_DEFECTO: kos20_Part3.jpg
#   DEFECTO: kos20_Part4.jpg
#   NO_DEFECTO: kos20_Part5.jpg
#   NO_DEFECTO: kos20_Part6.jpg
#   NO_DEFECTO: kos20_Part7.jpg
#
# Procesando kos21
#   NO_DEFECTO: kos21_Part0.jpg
#   NO_DEFECTO: kos21_Part1.jpg
#   NO_DEFECTO: kos21_Part2.jpg
#   NO_DEFECTO: kos21_Part3.jpg
#   NO_DEFECTO: kos21_Part4.jpg
#   DEFECTO: kos21_Part5.jpg
#   NO_DEFECTO: kos21_Part6.jpg
#
# Procesando kos22
#   NO_DEFECTO: kos22_Part0.jpg
#   NO_DEFECTO: kos22_Part1.jpg
#   NO_DEFECTO: kos22_Part2.jpg
#   NO_DEFECTO: kos22_Part3.jpg
#   NO_DEFECTO: kos22_Part4.jpg
#   NO_DEFECTO: kos22_Part5.jpg
#   DEFECTO: kos22_Part6.jpg
#   NO_DEFECTO: kos22_Part7.jpg
#
# Procesando kos23
#   NO_DEFECTO: kos23_Part0.jpg
#   NO_DEFECTO: kos23_Part1.jpg
#   NO_DEFECTO: kos23_Part2.jpg
#   NO_DEFECTO: kos23_Part3.jpg
#   NO_DEFECTO: kos23_Part4.jpg
#   NO_DEFECTO: kos23_Part5.jpg
#   DEFECTO: kos23_Part6.jpg
#   NO_DEFECTO: kos23_Part7.jpg
#
# Procesando kos24
#   NO_DEFECTO: kos24_Part0.jpg
#   DEFECTO: kos24_Part1.jpg
#   NO_DEFECTO: kos24_Part2.jpg
#   NO_DEFECTO: kos24_Part3.jpg
#   NO_DEFECTO: kos24_Part4.jpg
#   NO_DEFECTO: kos24_Part5.jpg
#   NO_DEFECTO: kos24_Part6.jpg
#   NO_DEFECTO: kos24_Part7.jpg
#
# Procesando kos25
#   NO_DEFECTO: kos25_Part0.jpg
#   NO_DEFECTO: kos25_Part1.jpg
#   NO_DEFECTO: kos25_Part2.jpg
#   NO_DEFECTO: kos25_Part3.jpg
#   DEFECTO: kos25_Part4.jpg
#   NO_DEFECTO: kos25_Part5.jpg
#   NO_DEFECTO: kos25_Part6.jpg
#   NO_DEFECTO: kos25_Part7.jpg
#
# Procesando kos26
#   NO_DEFECTO: kos26_Part0.jpg
#   NO_DEFECTO: kos26_Part1.jpg
#   NO_DEFECTO: kos26_Part2.jpg
#   NO_DEFECTO: kos26_Part3.jpg
#   NO_DEFECTO: kos26_Part4.jpg
#   DEFECTO: kos26_Part5.jpg
#   NO_DEFECTO: kos26_Part6.jpg
#   NO_DEFECTO: kos26_Part7.jpg
#
# Procesando kos27
#   DEFECTO: kos27_Part0.jpg
#   NO_DEFECTO: kos27_Part1.jpg
#   NO_DEFECTO: kos27_Part2.jpg
#   NO_DEFECTO: kos27_Part3.jpg
#   NO_DEFECTO: kos27_Part4.jpg
#   NO_DEFECTO: kos27_Part5.jpg
#   NO_DEFECTO: kos27_Part6.jpg
#   NO_DEFECTO: kos27_Part7.jpg
#
# Procesando kos28
#   NO_DEFECTO: kos28_Part0.jpg
#   NO_DEFECTO: kos28_Part1.jpg
#   NO_DEFECTO: kos28_Part2.jpg
#   DEFECTO: kos28_Part3.jpg
#   NO_DEFECTO: kos28_Part4.jpg
#   NO_DEFECTO: kos28_Part5.jpg
#   NO_DEFECTO: kos28_Part6.jpg
#   NO_DEFECTO: kos28_Part7.jpg
#
# Procesando kos29
#   DEFECTO: kos29_Part0.jpg
#   NO_DEFECTO: kos29_Part1.jpg
#   NO_DEFECTO: kos29_Part2.jpg
#   NO_DEFECTO: kos29_Part3.jpg
#   NO_DEFECTO: kos29_Part4.jpg
#   NO_DEFECTO: kos29_Part5.jpg
#   NO_DEFECTO: kos29_Part6.jpg
#   NO_DEFECTO: kos29_Part7.jpg
#
# Procesando kos30
#   DEFECTO: kos30_Part0.jpg
#   NO_DEFECTO: kos30_Part1.jpg
#   NO_DEFECTO: kos30_Part2.jpg
#   NO_DEFECTO: kos30_Part3.jpg
#   NO_DEFECTO: kos30_Part4.jpg
#   NO_DEFECTO: kos30_Part5.jpg
#   NO_DEFECTO: kos30_Part6.jpg
#   NO_DEFECTO: kos30_Part7.jpg
#
# Procesando kos31
#   NO_DEFECTO: kos31_Part0.jpg
#   DEFECTO: kos31_Part1.jpg
#   NO_DEFECTO: kos31_Part2.jpg
#   NO_DEFECTO: kos31_Part3.jpg
#   NO_DEFECTO: kos31_Part4.jpg
#   NO_DEFECTO: kos31_Part5.jpg
#   NO_DEFECTO: kos31_Part6.jpg
#   NO_DEFECTO: kos31_Part7.jpg
#
# Procesando kos32
#   NO_DEFECTO: kos32_Part0.jpg
#   NO_DEFECTO: kos32_Part1.jpg
#   DEFECTO: kos32_Part2.jpg
#   NO_DEFECTO: kos32_Part3.jpg
#   NO_DEFECTO: kos32_Part4.jpg
#   NO_DEFECTO: kos32_Part5.jpg
#   NO_DEFECTO: kos32_Part6.jpg
#   NO_DEFECTO: kos32_Part7.jpg
#
# Procesando kos33
#   NO_DEFECTO: kos33_Part0.jpg
#   NO_DEFECTO: kos33_Part1.jpg
#   NO_DEFECTO: kos33_Part2.jpg
#   NO_DEFECTO: kos33_Part3.jpg
#   NO_DEFECTO: kos33_Part4.jpg
#   NO_DEFECTO: kos33_Part5.jpg
#   DEFECTO: kos33_Part6.jpg
#   NO_DEFECTO: kos33_Part7.jpg
#
# Procesando kos34
#   DEFECTO: kos34_Part0.jpg
#   NO_DEFECTO: kos34_Part1.jpg
#   NO_DEFECTO: kos34_Part2.jpg
#   NO_DEFECTO: kos34_Part3.jpg
#   NO_DEFECTO: kos34_Part4.jpg
#   NO_DEFECTO: kos34_Part5.jpg
#   NO_DEFECTO: kos34_Part6.jpg
#   NO_DEFECTO: kos34_Part7.jpg
#
# Procesando kos35
#   NO_DEFECTO: kos35_Part0.jpg
#   NO_DEFECTO: kos35_Part1.jpg
#   NO_DEFECTO: kos35_Part2.jpg
#   NO_DEFECTO: kos35_Part3.jpg
#   NO_DEFECTO: kos35_Part4.jpg
#   DEFECTO: kos35_Part5.jpg
#   NO_DEFECTO: kos35_Part6.jpg
#   NO_DEFECTO: kos35_Part7.jpg
#
# Procesando kos36
#   NO_DEFECTO: kos36_Part0.jpg
#   NO_DEFECTO: kos36_Part1.jpg
#   NO_DEFECTO: kos36_Part2.jpg
#   DEFECTO: kos36_Part3.jpg
#   NO_DEFECTO: kos36_Part4.jpg
#   NO_DEFECTO: kos36_Part5.jpg
#   NO_DEFECTO: kos36_Part6.jpg
#   NO_DEFECTO: kos36_Part7.jpg
#
# Procesando kos37
#   DEFECTO: kos37_Part0.jpg
#   NO_DEFECTO: kos37_Part1.jpg
#   NO_DEFECTO: kos37_Part2.jpg
#   NO_DEFECTO: kos37_Part3.jpg
#   NO_DEFECTO: kos37_Part4.jpg
#   NO_DEFECTO: kos37_Part5.jpg
#   NO_DEFECTO: kos37_Part6.jpg
#   NO_DEFECTO: kos37_Part7.jpg
#
# Procesando kos38
#   DEFECTO: kos38_Part0.jpg
#   DEFECTO: kos38_Part1.jpg
#   NO_DEFECTO: kos38_Part2.jpg
#   NO_DEFECTO: kos38_Part3.jpg
#   NO_DEFECTO: kos38_Part4.jpg
#   NO_DEFECTO: kos38_Part5.jpg
#   NO_DEFECTO: kos38_Part6.jpg
#   NO_DEFECTO: kos38_Part7.jpg
#
# Procesando kos39
#   NO_DEFECTO: kos39_Part0.jpg
#   NO_DEFECTO: kos39_Part1.jpg
#   NO_DEFECTO: kos39_Part2.jpg
#   NO_DEFECTO: kos39_Part3.jpg
#   NO_DEFECTO: kos39_Part4.jpg
#   NO_DEFECTO: kos39_Part5.jpg
#   DEFECTO: kos39_Part6.jpg
#   DEFECTO: kos39_Part7.jpg
#
# Procesando kos40
#   NO_DEFECTO: kos40_Part0.jpg
#   NO_DEFECTO: kos40_Part1.jpg
#   NO_DEFECTO: kos40_Part2.jpg
#   NO_DEFECTO: kos40_Part3.jpg
#   NO_DEFECTO: kos40_Part4.jpg
#   DEFECTO: kos40_Part5.jpg
#   NO_DEFECTO: kos40_Part6.jpg
#   NO_DEFECTO: kos40_Part7.jpg
#
# Procesando kos41
#   NO_DEFECTO: kos41_Part0.jpg
#   NO_DEFECTO: kos41_Part1.jpg
#   NO_DEFECTO: kos41_Part2.jpg
#   NO_DEFECTO: kos41_Part3.jpg
#   NO_DEFECTO: kos41_Part4.jpg
#   NO_DEFECTO: kos41_Part5.jpg
#   NO_DEFECTO: kos41_Part6.jpg
#   DEFECTO: kos41_Part7.jpg
#
# Procesando kos42
#   NO_DEFECTO: kos42_Part0.jpg
#   NO_DEFECTO: kos42_Part1.jpg
#   NO_DEFECTO: kos42_Part2.jpg
#   DEFECTO: kos42_Part3.jpg
#   NO_DEFECTO: kos42_Part4.jpg
#   NO_DEFECTO: kos42_Part5.jpg
#   NO_DEFECTO: kos42_Part6.jpg
#   NO_DEFECTO: kos42_Part7.jpg
#
# Procesando kos43
#   NO_DEFECTO: kos43_Part0.jpg
#   DEFECTO: kos43_Part1.jpg
#   NO_DEFECTO: kos43_Part2.jpg
#   NO_DEFECTO: kos43_Part3.jpg
#   NO_DEFECTO: kos43_Part4.jpg
#   NO_DEFECTO: kos43_Part5.jpg
#   NO_DEFECTO: kos43_Part6.jpg
#   NO_DEFECTO: kos43_Part7.jpg
#
# Procesando kos44
#   NO_DEFECTO: kos44_Part0.jpg
#   NO_DEFECTO: kos44_Part1.jpg
#   NO_DEFECTO: kos44_Part2.jpg
#   NO_DEFECTO: kos44_Part3.jpg
#   NO_DEFECTO: kos44_Part4.jpg
#   NO_DEFECTO: kos44_Part5.jpg
#   DEFECTO: kos44_Part6.jpg
#   NO_DEFECTO: kos44_Part7.jpg
#
# Procesando kos45
#   NO_DEFECTO: kos45_Part0.jpg
#   NO_DEFECTO: kos45_Part1.jpg
#   NO_DEFECTO: kos45_Part2.jpg
#   DEFECTO: kos45_Part3.jpg
#   NO_DEFECTO: kos45_Part4.jpg
#   NO_DEFECTO: kos45_Part5.jpg
#   NO_DEFECTO: kos45_Part6.jpg
#   NO_DEFECTO: kos45_Part7.jpg
#
# Procesando kos46
#   NO_DEFECTO: kos46_Part0.jpg
#   NO_DEFECTO: kos46_Part1.jpg
#   NO_DEFECTO: kos46_Part2.jpg
#   NO_DEFECTO: kos46_Part3.jpg
#   NO_DEFECTO: kos46_Part4.jpg
#   NO_DEFECTO: kos46_Part5.jpg
#   NO_DEFECTO: kos46_Part6.jpg
#   DEFECTO: kos46_Part7.jpg
#
# Procesando kos47
#   NO_DEFECTO: kos47_Part0.jpg
#   NO_DEFECTO: kos47_Part1.jpg
#   DEFECTO: kos47_Part2.jpg
#   NO_DEFECTO: kos47_Part3.jpg
#   NO_DEFECTO: kos47_Part4.jpg
#   NO_DEFECTO: kos47_Part5.jpg
#   NO_DEFECTO: kos47_Part6.jpg
#   NO_DEFECTO: kos47_Part7.jpg
#
# Procesando kos48
#   NO_DEFECTO: kos48_Part0.jpg
#   NO_DEFECTO: kos48_Part1.jpg
#   NO_DEFECTO: kos48_Part2.jpg
#   NO_DEFECTO: kos48_Part3.jpg
#   NO_DEFECTO: kos48_Part4.jpg
#   DEFECTO: kos48_Part5.jpg
#   NO_DEFECTO: kos48_Part6.jpg
#   NO_DEFECTO: kos48_Part7.jpg
#
# Procesando kos49
#   NO_DEFECTO: kos49_Part0.jpg
#   NO_DEFECTO: kos49_Part1.jpg
#   DEFECTO: kos49_Part2.jpg
#   NO_DEFECTO: kos49_Part3.jpg
#   NO_DEFECTO: kos49_Part4.jpg
#   NO_DEFECTO: kos49_Part5.jpg
#   NO_DEFECTO: kos49_Part6.jpg
#   NO_DEFECTO: kos49_Part7.jpg
#
# Procesando kos50
#   NO_DEFECTO: kos50_Part0.jpg
#   NO_DEFECTO: kos50_Part1.jpg
#   NO_DEFECTO: kos50_Part2.jpg
#   NO_DEFECTO: kos50_Part3.jpg
#   DEFECTO: kos50_Part4.jpg
#   NO_DEFECTO: kos50_Part5.jpg
#   NO_DEFECTO: kos50_Part6.jpg
#   NO_DEFECTO: kos50_Part7.jpg
#
# ===== RESUMEN FINAL =====
# Total imágenes procesadas: 399
# Defecto: 52
# No defecto: 347

# %%
from pathlib import Path
import shutil
import random

# =========================
# CONFIG
# =========================
SOURCE_DIR = Path("data_imagenes/clasificados")  # aquí están defecto/ y no_defecto/
OUT_DIR = Path("dataset_cls")

SPLIT = {"train": 0.70, "val": 0.15, "test": 0.15}
SEED = 42

classes = ["defecto", "no_defecto"]

random.seed(SEED)

# Validación de splits
if abs(sum(SPLIT.values()) - 1.0) > 1e-9:
    raise ValueError("Los porcentajes de SPLIT deben sumar 1.0")

# Crear carpetas de salida
for split in SPLIT:
    for cls in classes:
        (OUT_DIR / split / cls).mkdir(parents=True, exist_ok=True)

# =========================
# FUNCIÓN DE SPLIT
# =========================
def split_list(items, split_dict):
    """Devuelve dict con listas para train/val/test respetando proporciones."""
    n = len(items)
    n_train = int(n * split_dict["train"])
    n_val = int(n * split_dict["val"])
    # el resto para test para asegurar que suma n
    n_test = n - n_train - n_val

    train_items = items[:n_train]
    val_items = items[n_train:n_train + n_val]
    test_items = items[n_train + n_val:]

    assert len(test_items) == n_test
    return {"train": train_items, "val": val_items, "test": test_items}

# =========================
# PROCESO POR CLASE (estratificado)
# =========================
for cls in classes:
    src_cls_dir = SOURCE_DIR / cls
    imgs = list(src_cls_dir.glob("*.jpg"))

    if len(imgs) == 0:
        raise ValueError(f"No hay imágenes .jpg en {src_cls_dir}")

    random.shuffle(imgs)
    parts = split_list(imgs, SPLIT)

    for split_name, split_imgs in parts.items():
        for img_path in split_imgs:
            shutil.copy(img_path, OUT_DIR / split_name / cls / img_path.name)

    print(f"\nClase '{cls}':")
    for split_name in ["train", "val", "test"]:
        print(f"  {split_name}: {len(parts[split_name])} imágenes")

print("\n✅ Dataset creado en:", OUT_DIR.resolve())
# Out:
# Clase 'defecto':
#   train: 36 imágenes
#   val: 7 imágenes
#   test: 9 imágenes
#
# Clase 'no_defecto':
#   train: 242 imágenes
#   val: 52 imágenes
#   test: 53 imágenes
#
# ✅ Dataset creado en: C:\Users\aneli\OneDrive\Documentos\GitHub\grupo1reto2\dataset_cls
