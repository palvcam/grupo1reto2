# %% [markdown]
# # Preparación del entorno

# %%
from ultralytics import YOLO
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import (
    accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay
)

# Rutas
DATASET_DIR = Path("dataset_cls")
TRAIN_DIR = DATASET_DIR / "train"
VAL_DIR   = DATASET_DIR / "val"
TEST_DIR  = DATASET_DIR / "test"

assert TRAIN_DIR.exists() and VAL_DIR.exists() and TEST_DIR.exists(), "Revisa rutas train/val/test"

# Clases
CLASSES = sorted([d.name for d in TRAIN_DIR.iterdir() if d.is_dir()])
print("Clases:", CLASSES)

# Modelo base (clasificación)
BASE_MODEL = "yolo11s-cls.pt"
# Out:
# Clases: ['defecto', 'no_defecto']

# %% [markdown]
# # Predecir carpeta + sacar DF

# %%
def predict_folder_to_df(model: YOLO, folder: Path, classes: list[str], imgsz: int = 224):
    image_paths = [p for p in folder.rglob("*") if p.suffix.lower() in [".jpg",".jpeg",".png",".bmp",".tif",".tiff"]]
    rows = []
    for img_path in image_paths:
        r = model.predict(img_path, imgsz=imgsz, verbose=False)[0]
        pred_id = int(r.probs.top1)
        conf = float(r.probs.top1conf)
        pred_name = r.names[pred_id]
        true_name = img_path.parent.name  # nombre carpeta = etiqueta real

        rows.append({
            "image_path": str(img_path),
            "image": img_path.name,
            "true_class": true_name,
            "pred_class": pred_name,
            "confidence": conf
        })
    return pd.DataFrame(rows)

# %% [markdown]
# # Métricas poniendo el foco en el defecto

# %%
def compute_metrics_binary(df_pred: pd.DataFrame, positive_class: str = "defecto"):
    y_true = df_pred["true_class"].tolist()
    y_pred = df_pred["pred_class"].tolist()

    acc = accuracy_score(y_true, y_pred)

    # Para binario, calculamos precision/recall/f1 para la clase positiva
    report = classification_report(y_true, y_pred, digits=4, output_dict=True, zero_division=0)
    pos = report.get(positive_class, {"precision":0, "recall":0, "f1-score":0})

    return {
        "accuracy": acc,
        f"precision_{positive_class}": pos["precision"],
        f"recall_{positive_class}": pos["recall"],
        f"f1_{positive_class}": pos["f1-score"],
        "report_dict": report
    }

# %% [markdown]
# # Entrenar 1 experimento (“final” de prueba)

# %%
RUN_NAME = "final_train"

model = YOLO(BASE_MODEL)
train_res = model.train(
    data=str(DATASET_DIR),
    epochs=50,
    imgsz=224,
    batch=32,
    patience=10,
    optimizer="Adam",
    lr0=1e-3,
    project="runs_cls",
    name=RUN_NAME,
    verbose=True
)

BEST_PT = Path(train_res.save_dir) / "weights" / "best.pt"
print("Best model:", BEST_PT)
# Out:
# New https://pypi.org/project/ultralytics/8.4.7 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.252  Python-3.13.5 torch-2.9.1+cpu CPU (Intel Core(TM) Ultra 7 165H)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=dataset_cls, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=final_train4, nbs=64, nms=False, opset=None, optimize=False, optimizer=Adam, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs_cls, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\final_train4, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\train... found 138 images in 2 classes
# val: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\val... found 29 images in 2 classes
# test: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\test... found 32 images in 2 classes
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  10                  -1  1    660482  ultralytics.nn.modules.head.Classify         [512, 2]
# YOLO11s-cls summary: 86 layers, 5,445,570 parameters, 5,445,570 gradients, 12.1 GFLOPs
# Transferred 234/236 items from pretrained weights
# train: Fast image access  (ping: 0.10.0 ms, read: 15.72.3 MB/s, size: 258.8 KB)
# train: Scanning C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\train... 138 images, 0 corrupt: 100% ━━━━━━━━━━━━ 138/138 564.7it/s 0.2s0.1s
# train: New cache created: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\train.cache
# val: Fast image access  (ping: 0.00.0 ms, read: 16.43.2 MB/s, size: 252.5 KB)
# val: Scanning C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\val... 29 images, 0 corrupt: 100% ━━━━━━━━━━━━ 29/29 650.1it/s 0.0s
# val: New cache created: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\val.cache
# optimizer: Adam(lr=0.001, momentum=0.937) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 0 dataloader workers
# Logging results to C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\final_train4
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/50         0G     0.6206         10        224: 100% ━━━━━━━━━━━━ 5/5 1.2s/it 6.2s1.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.7it/s 0.6s
#                    all      0.862          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/50         0G     0.4304         10        224: 100% ━━━━━━━━━━━━ 5/5 1.2s/it 6.0s1.2ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all      0.862          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/50         0G     0.3921         10        224: 100% ━━━━━━━━━━━━ 5/5 1.2s/it 6.1s1.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.7it/s 0.6s
#                    all      0.862          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/50         0G     0.2046         10        224: 100% ━━━━━━━━━━━━ 5/5 1.3s/it 6.3s1.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/50         0G     0.2384         10        224: 100% ━━━━━━━━━━━━ 5/5 1.4s/it 6.8s1.2ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/50         0G     0.2457         10        224: 100% ━━━━━━━━━━━━ 5/5 1.3s/it 6.7s1.3ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/50         0G     0.1318         10        224: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s1.4ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/50         0G     0.1261         10        224: 100% ━━━━━━━━━━━━ 5/5 1.4s/it 6.9s1.2ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/50         0G     0.1805         10        224: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.3s1.4ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.3it/s 0.8s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/50         0G     0.1116         10        224: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.4s1.3ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.4it/s 0.7s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/50         0G     0.1869         10        224: 100% ━━━━━━━━━━━━ 5/5 1.4s/it 7.1s1.2ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/50         0G     0.1431         10        224: 100% ━━━━━━━━━━━━ 5/5 1.4s/it 7.1s1.3ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/50         0G    0.07471         10        224: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.6s1.3ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.4it/s 0.7s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/50         0G    0.08827         10        224: 100% ━━━━━━━━━━━━ 5/5 1.4s/it 6.9s1.3ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/50         0G     0.1169         10        224: 100% ━━━━━━━━━━━━ 5/5 1.4s/it 7.2s1.2ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/50         0G      0.132         10        224: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.3s1.2ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all      0.966          1
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 6, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 16 epochs completed in 0.035 hours.
# Optimizer stripped from C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\final_train4\weights\last.pt, 11.0MB
# Optimizer stripped from C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\final_train4\weights\best.pt, 11.0MB
#
# Validating C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\final_train4\weights\best.pt...
# Ultralytics 8.3.252  Python-3.13.5 torch-2.9.1+cpu CPU (Intel Core(TM) Ultra 7 165H)
# YOLO11s-cls summary (fused): 47 layers, 5,436,690 parameters, 0 gradients, 12.0 GFLOPs
# train: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\train... found 138 images in 2 classes
# val: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\val... found 29 images in 2 classes
# test: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\test... found 32 images in 2 classes
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all          1          1
# Speed: 0.0ms preprocess, 10.4ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\final_train4
# Best model: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\final_train4\weights\best.pt

# %% [markdown]
# # Evaluación en TEST (con matriz de confusión + CSV)

# %%
model_best = YOLO(str(BEST_PT))

df_test = predict_folder_to_df(model_best, TEST_DIR, CLASSES, imgsz=224)
display(df_test.head())

df_test.to_csv("predicciones_test.csv", index=False)
print("CSV guardado: predicciones_test.csv")

# Métricas
m = compute_metrics_binary(df_test, positive_class="defecto")
print(f"Accuracy test: {m['accuracy']:.4f}")
print(f"Recall defecto: {m['recall_defecto']:.4f}")
print(f"F1 defecto: {m['f1_defecto']:.4f}")

# Report
print("\n=== Classification Report ===")
print(classification_report(df_test["true_class"], df_test["pred_class"], digits=4, zero_division=0))

# Matriz de confusión
labels = CLASSES
cm = confusion_matrix(df_test["true_class"], df_test["pred_class"], labels=labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(values_format="d")
plt.title("Confusion Matrix — TEST")
plt.show()
# Out:
#                                  image_path            image true_class  \
# 0  dataset_cls\test\defecto\kos01_Part5.jpg  kos01_Part5.jpg    defecto
# 1  dataset_cls\test\defecto\kos05_Part5.jpg  kos05_Part5.jpg    defecto
# 2  dataset_cls\test\defecto\kos14_Part7.jpg  kos14_Part7.jpg    defecto
# 3  dataset_cls\test\defecto\kos38_Part0.jpg  kos38_Part0.jpg    defecto
# 4  dataset_cls\test\defecto\kos41_Part7.jpg  kos41_Part7.jpg    defecto
#
#    pred_class  confidence
# 0     defecto    0.999930
# 1     defecto    1.000000
# 2  no_defecto    0.999968
# 3     defecto    0.560327
# 4     defecto    1.000000
# CSV guardado: predicciones_test.csv
# Accuracy test: 0.9688
# Recall defecto: 0.8000
# F1 defecto: 0.8889
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#      defecto     1.0000    0.8000    0.8889         5
#   no_defecto     0.9643    1.0000    0.9818        27
#
#     accuracy                         0.9688        32
#    macro avg     0.9821    0.9000    0.9354        32
# weighted avg     0.9699    0.9688    0.9673        32

# %% [markdown]
# # Errores más graves (alta confianza pero mal)

# %%
df_errors = df_test[df_test["true_class"] != df_test["pred_class"]].copy()
df_errors = df_errors.sort_values("confidence", ascending=False)

print("Errores:", len(df_errors))
display(df_errors.head(15))
# Out:
# Errores: 1
#                                  image_path            image true_class  \
# 2  dataset_cls\test\defecto\kos14_Part7.jpg  kos14_Part7.jpg    defecto
#
#    pred_class  confidence
# 2  no_defecto    0.999968

# %% [markdown]
# # Grid-search (guardar CSV + eligir el mejor)

# %%
import itertools
from pathlib import Path
import pandas as pd

GRID = {
    "imgsz": [224],
    "batch": [16, 32],
    "lr0": [1e-3, 5e-4],
    "epochs": [100],
    "optimizer": ["Adam"],
    "patience": [10],         # early stopping
}

SELECT_BY = "recall_defecto"

experiments = list(itertools.product(
    GRID["imgsz"], GRID["batch"], GRID["lr0"], GRID["epochs"], GRID["optimizer"], GRID["patience"]
))

all_rows = []

for i, (imgsz, batch, lr0, epochs, optimizer, patience) in enumerate(experiments, start=1):
    exp_name = f"exp{i}_img{imgsz}_b{batch}_lr{lr0}_e{epochs}_{optimizer}_pat{patience}"
    print("\n==>", exp_name)

    model = YOLO(BASE_MODEL)
    train_res = model.train(
        data=str(DATASET_DIR),
        imgsz=imgsz,
        batch=batch,
        lr0=lr0,
        epochs=epochs,
        optimizer=optimizer,
        patience=patience,
        val=True,
        project="runs_cls",
        name=exp_name,
        verbose=False
    )

    best_pt = Path(train_res.save_dir) / "weights" / "best.pt"
    model_best = YOLO(str(best_pt))

    df_test = predict_folder_to_df(model_best, TEST_DIR, CLASSES, imgsz=imgsz)
    metrics = compute_metrics_binary(df_test, positive_class="defecto")

    all_rows.append({
        "exp_name": exp_name,
        "best_pt": str(best_pt),
        "imgsz": imgsz,
        "batch": batch,
        "lr0": lr0,
        "epochs_max": epochs,
        "patience": patience,
        "accuracy": metrics["accuracy"],
        "precision_defecto": metrics["precision_defecto"],
        "recall_defecto": metrics["recall_defecto"],
        "f1_defecto": metrics["f1_defecto"],
    })

df_grid = pd.DataFrame(all_rows)
df_grid.to_csv("grid_results.csv", index=False)
display(df_grid.sort_values(SELECT_BY, ascending=False).head(10))
print("Guardado: grid_results.csv")
# Out:
# ==> exp1_img224_b16_lr0.001_e100_Adam_pat10
# New https://pypi.org/project/ultralytics/8.4.7 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.252  Python-3.13.5 torch-2.9.1+cpu CPU (Intel Core(TM) Ultra 7 165H)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=dataset_cls, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=exp1_img224_b16_lr0.001_e100_Adam_pat104, nbs=64, nms=False, opset=None, optimize=False, optimizer=Adam, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs_cls, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\exp1_img224_b16_lr0.001_e100_Adam_pat104, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\train... found 138 images in 2 classes
# val: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\val... found 29 images in 2 classes
# test: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\test... found 32 images in 2 classes
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  10                  -1  1    660482  ultralytics.nn.modules.head.Classify         [512, 2]
# YOLO11s-cls summary: 86 layers, 5,445,570 parameters, 5,445,570 gradients, 12.1 GFLOPs
# Transferred 234/236 items from pretrained weights
# train: Fast image access  (ping: 0.00.0 ms, read: 657.5151.4 MB/s, size: 258.8 KB)
# train: Scanning C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\train... 138 images, 0 corrupt: 100% ━━━━━━━━━━━━ 138/138 28.9Mit/s 0.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 1039.1150.9 MB/s, size: 252.5 KB)
# val: Scanning C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\val... 29 images, 0 corrupt: 100% ━━━━━━━━━━━━ 29/29 7.6Mit/s 0.0s
# optimizer: Adam(lr=0.001, momentum=0.937) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 0 dataloader workers
# Logging results to C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\exp1_img224_b16_lr0.001_e100_Adam_pat104
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#       1/100         0G     0.5625         10        224: 100% ━━━━━━━━━━━━ 9/9 1.2it/s 7.6s0.8ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.7it/s 0.6s
#                    all      0.862          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       2/100         0G     0.3834         10        224: 100% ━━━━━━━━━━━━ 9/9 1.3it/s 7.0s0.7ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all      0.862          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       3/100         0G     0.3274         10        224: 100% ━━━━━━━━━━━━ 9/9 1.4it/s 6.5s0.7ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       4/100         0G     0.1826         10        224: 100% ━━━━━━━━━━━━ 9/9 1.3it/s 7.0s0.7ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       5/100         0G     0.1604         10        224: 100% ━━━━━━━━━━━━ 9/9 1.2it/s 7.3s0.9ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       6/100         0G     0.1758         10        224: 100% ━━━━━━━━━━━━ 9/9 1.4it/s 6.5s0.7ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       7/100         0G     0.1217         10        224: 100% ━━━━━━━━━━━━ 9/9 1.4it/s 6.4s0.7ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.7it/s 0.6s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       8/100         0G     0.1988         10        224: 100% ━━━━━━━━━━━━ 9/9 1.3it/s 6.9s0.7ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.9it/s 0.5s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       9/100         0G     0.2016         10        224: 100% ━━━━━━━━━━━━ 9/9 1.4it/s 6.4s0.7ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.7it/s 0.6s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      10/100         0G     0.2376         10        224: 100% ━━━━━━━━━━━━ 9/9 1.4it/s 6.6s0.7ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all      0.931          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      11/100         0G     0.1627         10        224: 100% ━━━━━━━━━━━━ 9/9 1.3it/s 7.0s0.8ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      12/100         0G     0.1581         10        224: 100% ━━━━━━━━━━━━ 9/9 1.3it/s 6.8s0.7ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.8it/s 0.6s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      13/100         0G     0.1234         10        224: 100% ━━━━━━━━━━━━ 9/9 1.3it/s 6.8s0.8ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      14/100         0G     0.1064         10        224: 100% ━━━━━━━━━━━━ 9/9 1.3it/s 6.8s0.7ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      15/100         0G     0.3486         10        224: 100% ━━━━━━━━━━━━ 9/9 1.3it/s 6.9s0.8ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      16/100         0G     0.2639         10        224: 100% ━━━━━━━━━━━━ 9/9 1.2it/s 7.4s0.8ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      17/100         0G     0.1609         10        224: 100% ━━━━━━━━━━━━ 9/9 1.2it/s 7.7s0.9ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.4it/s 0.7s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      18/100         0G      0.194         10        224: 100% ━━━━━━━━━━━━ 9/9 1.2it/s 7.3s0.8ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all      0.931          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      19/100         0G     0.3019         10        224: 100% ━━━━━━━━━━━━ 9/9 1.3it/s 6.8s0.7ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      20/100         0G     0.2036         10        224: 100% ━━━━━━━━━━━━ 9/9 1.3it/s 7.2s0.8ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.7it/s 0.6s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      21/100         0G      0.192         10        224: 100% ━━━━━━━━━━━━ 9/9 1.3it/s 6.7s0.7ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all      0.966          1
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 11, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 21 epochs completed in 0.046 hours.
# Optimizer stripped from C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\exp1_img224_b16_lr0.001_e100_Adam_pat104\weights\last.pt, 11.0MB
# Optimizer stripped from C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\exp1_img224_b16_lr0.001_e100_Adam_pat104\weights\best.pt, 11.0MB
#
# Validating C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\exp1_img224_b16_lr0.001_e100_Adam_pat104\weights\best.pt...
# Ultralytics 8.3.252  Python-3.13.5 torch-2.9.1+cpu CPU (Intel Core(TM) Ultra 7 165H)
# YOLO11s-cls summary (fused): 47 layers, 5,436,690 parameters, 0 gradients, 12.0 GFLOPs
# train: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\train... found 138 images in 2 classes
# val: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\val... found 29 images in 2 classes
# test: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\test... found 32 images in 2 classes
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.7it/s 0.6s
#                    all          1          1
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\exp1_img224_b16_lr0.001_e100_Adam_pat104
#
# ==> exp2_img224_b16_lr0.0005_e100_Adam_pat10
# New https://pypi.org/project/ultralytics/8.4.7 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.252  Python-3.13.5 torch-2.9.1+cpu CPU (Intel Core(TM) Ultra 7 165H)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=dataset_cls, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.0005, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=exp2_img224_b16_lr0.0005_e100_Adam_pat104, nbs=64, nms=False, opset=None, optimize=False, optimizer=Adam, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs_cls, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\exp2_img224_b16_lr0.0005_e100_Adam_pat104, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\train... found 138 images in 2 classes
# val: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\val... found 29 images in 2 classes
# test: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\test... found 32 images in 2 classes
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  10                  -1  1    660482  ultralytics.nn.modules.head.Classify         [512, 2]
# YOLO11s-cls summary: 86 layers, 5,445,570 parameters, 5,445,570 gradients, 12.1 GFLOPs
# Transferred 234/236 items from pretrained weights
# train: Fast image access  (ping: 0.00.0 ms, read: 908.5197.5 MB/s, size: 258.8 KB)
# train: Scanning C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\train... 138 images, 0 corrupt: 100% ━━━━━━━━━━━━ 138/138 25.2Mit/s 0.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 1088.4135.2 MB/s, size: 252.5 KB)
# val: Scanning C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\val... 29 images, 0 corrupt: 100% ━━━━━━━━━━━━ 29/29 8.7Mit/s 0.0s
# optimizer: Adam(lr=0.0005, momentum=0.937) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 0 dataloader workers
# Logging results to C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\exp2_img224_b16_lr0.0005_e100_Adam_pat104
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#       1/100         0G      0.558         10        224: 100% ━━━━━━━━━━━━ 9/9 1.2it/s 7.4s0.8ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all      0.862          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       2/100         0G     0.3888         10        224: 100% ━━━━━━━━━━━━ 9/9 1.1it/s 8.4s1.0ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.2it/s 0.9s
#                    all      0.862          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       3/100         0G     0.3418         10        224: 100% ━━━━━━━━━━━━ 9/9 1.2s/it 11.2s1.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.2it/s 0.9s
#                    all      0.931          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       4/100         0G     0.2001         10        224: 100% ━━━━━━━━━━━━ 9/9 1.1s/it 9.8s1.0ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       5/100         0G     0.1734         10        224: 100% ━━━━━━━━━━━━ 9/9 1.0it/s 8.9s1.0ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.2it/s 0.8s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       6/100         0G     0.1409         10        224: 100% ━━━━━━━━━━━━ 9/9 1.1s/it 10.3s1.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.2it/s 0.8s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       7/100         0G     0.1801         10        224: 100% ━━━━━━━━━━━━ 9/9 1.1s/it 9.5s1.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.2it/s 0.8s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       8/100         0G     0.1259         10        224: 100% ━━━━━━━━━━━━ 9/9 1.3s/it 11.3s1.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.0it/s 1.0s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       9/100         0G     0.3301         10        224: 100% ━━━━━━━━━━━━ 9/9 1.2s/it 10.7s1.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.2it/s 0.8s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      10/100         0G     0.2737         10        224: 100% ━━━━━━━━━━━━ 9/9 1.1s/it 9.9s1.2ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      11/100         0G     0.1694         10        224: 100% ━━━━━━━━━━━━ 9/9 1.1s/it 10.1s1.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.0s/it 1.0s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      12/100         0G     0.1464         10        224: 100% ━━━━━━━━━━━━ 9/9 1.1s/it 10.1s1.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.2it/s 0.8s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      13/100         0G     0.1194         10        224: 100% ━━━━━━━━━━━━ 9/9 1.0s/it 9.2s0.9ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.0it/s 1.0s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      14/100         0G      0.134         10        224: 100% ━━━━━━━━━━━━ 9/9 1.2s/it 10.5s1.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      15/100         0G    0.09762         10        224: 100% ━━━━━━━━━━━━ 9/9 1.2s/it 10.7s1.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          1          1
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 5, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 15 epochs completed in 0.047 hours.
# Optimizer stripped from C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\exp2_img224_b16_lr0.0005_e100_Adam_pat104\weights\last.pt, 11.0MB
# Optimizer stripped from C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\exp2_img224_b16_lr0.0005_e100_Adam_pat104\weights\best.pt, 11.0MB
#
# Validating C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\exp2_img224_b16_lr0.0005_e100_Adam_pat104\weights\best.pt...
# Ultralytics 8.3.252  Python-3.13.5 torch-2.9.1+cpu CPU (Intel Core(TM) Ultra 7 165H)
# YOLO11s-cls summary (fused): 47 layers, 5,436,690 parameters, 0 gradients, 12.0 GFLOPs
# train: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\train... found 138 images in 2 classes
# val: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\val... found 29 images in 2 classes
# test: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\test... found 32 images in 2 classes
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.3it/s 0.8s
#                    all          1          1
# Speed: 0.0ms preprocess, 11.4ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\exp2_img224_b16_lr0.0005_e100_Adam_pat104
#
# ==> exp3_img224_b32_lr0.001_e100_Adam_pat10
# New https://pypi.org/project/ultralytics/8.4.7 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.252  Python-3.13.5 torch-2.9.1+cpu CPU (Intel Core(TM) Ultra 7 165H)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=dataset_cls, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=exp3_img224_b32_lr0.001_e100_Adam_pat104, nbs=64, nms=False, opset=None, optimize=False, optimizer=Adam, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs_cls, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\exp3_img224_b32_lr0.001_e100_Adam_pat104, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\train... found 138 images in 2 classes
# val: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\val... found 29 images in 2 classes
# test: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\test... found 32 images in 2 classes
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  10                  -1  1    660482  ultralytics.nn.modules.head.Classify         [512, 2]
# YOLO11s-cls summary: 86 layers, 5,445,570 parameters, 5,445,570 gradients, 12.1 GFLOPs
# Transferred 234/236 items from pretrained weights
# train: Fast image access  (ping: 0.00.0 ms, read: 797.9120.1 MB/s, size: 258.8 KB)
# train: Scanning C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\train... 138 images, 0 corrupt: 100% ━━━━━━━━━━━━ 138/138 23.2Mit/s 0.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 740.9162.4 MB/s, size: 252.5 KB)
# val: Scanning C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\val... 29 images, 0 corrupt: 100% ━━━━━━━━━━━━ 29/29 5.8Mit/s 0.0s
# optimizer: Adam(lr=0.001, momentum=0.937) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 0 dataloader workers
# Logging results to C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\exp3_img224_b32_lr0.001_e100_Adam_pat104
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#       1/100         0G     0.6206         10        224: 100% ━━━━━━━━━━━━ 5/5 1.9s/it 9.3s1.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.3it/s 0.8s
#                    all      0.862          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       2/100         0G     0.4304         10        224: 100% ━━━━━━━━━━━━ 5/5 1.8s/it 8.9s2.3ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6s/it 1.6s
#                    all      0.862          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       3/100         0G     0.3915         10        224: 100% ━━━━━━━━━━━━ 5/5 2.3s/it 11.7s3.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.7s/it 1.7s
#                    all      0.862          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       4/100         0G     0.2027         10        224: 100% ━━━━━━━━━━━━ 5/5 2.2s/it 10.9s1.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.2it/s 0.9s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       5/100         0G     0.2409         10        224: 100% ━━━━━━━━━━━━ 5/5 1.7s/it 8.7s1.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.2it/s 0.8s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       6/100         0G     0.2528         10        224: 100% ━━━━━━━━━━━━ 5/5 2.0s/it 9.8s1.7ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.3it/s 0.8s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       7/100         0G     0.1346         10        224: 100% ━━━━━━━━━━━━ 5/5 1.9s/it 9.4s1.8ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.0s/it 1.0s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       8/100         0G     0.1329         10        224: 100% ━━━━━━━━━━━━ 5/5 1.9s/it 9.6s1.7ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.3it/s 0.8s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       9/100         0G     0.1964         10        224: 100% ━━━━━━━━━━━━ 5/5 2.0s/it 10.2s1.8ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      10/100         0G     0.1109         10        224: 100% ━━━━━━━━━━━━ 5/5 1.8s/it 9.0s1.7ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.2it/s 0.9s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      11/100         0G     0.1796         10        224: 100% ━━━━━━━━━━━━ 5/5 1.5s/it 7.7s1.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.3it/s 0.8s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      12/100         0G     0.1381         10        224: 100% ━━━━━━━━━━━━ 5/5 1.8s/it 9.1s1.7ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.2it/s 0.8s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      13/100         0G      0.104         10        224: 100% ━━━━━━━━━━━━ 5/5 1.7s/it 8.7s1.7ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      14/100         0G     0.1143         10        224: 100% ━━━━━━━━━━━━ 5/5 1.8s/it 8.9s1.7ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.2it/s 0.8s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      15/100         0G     0.1719         10        224: 100% ━━━━━━━━━━━━ 5/5 1.9s/it 9.7s1.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.3it/s 0.8s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      16/100         0G      0.156         10        224: 100% ━━━━━━━━━━━━ 5/5 1.7s/it 8.3s1.7ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all      0.966          1
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 6, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 16 epochs completed in 0.048 hours.
# Optimizer stripped from C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\exp3_img224_b32_lr0.001_e100_Adam_pat104\weights\last.pt, 11.0MB
# Optimizer stripped from C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\exp3_img224_b32_lr0.001_e100_Adam_pat104\weights\best.pt, 11.0MB
#
# Validating C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\exp3_img224_b32_lr0.001_e100_Adam_pat104\weights\best.pt...
# Ultralytics 8.3.252  Python-3.13.5 torch-2.9.1+cpu CPU (Intel Core(TM) Ultra 7 165H)
# YOLO11s-cls summary (fused): 47 layers, 5,436,690 parameters, 0 gradients, 12.0 GFLOPs
# train: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\train... found 138 images in 2 classes
# val: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\val... found 29 images in 2 classes
# test: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\test... found 32 images in 2 classes
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all          1          1
# Speed: 0.0ms preprocess, 12.9ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\exp3_img224_b32_lr0.001_e100_Adam_pat104
#
# ==> exp4_img224_b32_lr0.0005_e100_Adam_pat10
# New https://pypi.org/project/ultralytics/8.4.7 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.252  Python-3.13.5 torch-2.9.1+cpu CPU (Intel Core(TM) Ultra 7 165H)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=dataset_cls, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.0005, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=exp4_img224_b32_lr0.0005_e100_Adam_pat104, nbs=64, nms=False, opset=None, optimize=False, optimizer=Adam, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs_cls, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\exp4_img224_b32_lr0.0005_e100_Adam_pat104, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\train... found 138 images in 2 classes
# val: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\val... found 29 images in 2 classes
# test: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\test... found 32 images in 2 classes
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  10                  -1  1    660482  ultralytics.nn.modules.head.Classify         [512, 2]
# YOLO11s-cls summary: 86 layers, 5,445,570 parameters, 5,445,570 gradients, 12.1 GFLOPs
# Transferred 234/236 items from pretrained weights
# train: Fast image access  (ping: 0.00.0 ms, read: 1380.2301.8 MB/s, size: 258.8 KB)
# train: Scanning C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\train... 138 images, 0 corrupt: 100% ━━━━━━━━━━━━ 138/138 30.5Mit/s 0.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 724.0159.4 MB/s, size: 252.5 KB)
# val: Scanning C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\val... 29 images, 0 corrupt: 100% ━━━━━━━━━━━━ 29/29 6.1Mit/s 0.0s
# optimizer: Adam(lr=0.0005, momentum=0.937) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 0 dataloader workers
# Logging results to C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\exp4_img224_b32_lr0.0005_e100_Adam_pat104
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#       1/100         0G     0.6191         10        224: 100% ━━━━━━━━━━━━ 5/5 1.8s/it 8.9s1.8ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.2it/s 0.8s
#                    all      0.862          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       2/100         0G     0.4276         10        224: 100% ━━━━━━━━━━━━ 5/5 1.8s/it 8.8s1.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.2it/s 0.9s
#                    all      0.862          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       3/100         0G     0.4142         10        224: 100% ━━━━━━━━━━━━ 5/5 1.6s/it 8.2s1.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.3it/s 0.8s
#                    all      0.862          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       4/100         0G     0.2668         10        224: 100% ━━━━━━━━━━━━ 5/5 1.8s/it 9.0s1.8ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.2it/s 0.8s
#                    all      0.897          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       5/100         0G     0.2379         10        224: 100% ━━━━━━━━━━━━ 5/5 1.7s/it 8.4s1.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.3it/s 0.8s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       6/100         0G     0.2428         10        224: 100% ━━━━━━━━━━━━ 5/5 1.8s/it 8.8s1.7ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.3it/s 0.8s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       7/100         0G     0.1273         10        224: 100% ━━━━━━━━━━━━ 5/5 2.0s/it 10.2s1.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.2it/s 0.8s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       8/100         0G      0.124         10        224: 100% ━━━━━━━━━━━━ 5/5 1.6s/it 8.1s1.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       9/100         0G     0.1118         10        224: 100% ━━━━━━━━━━━━ 5/5 1.6s/it 8.2s1.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      10/100         0G    0.08912         10        224: 100% ━━━━━━━━━━━━ 5/5 1.9s/it 9.4s1.9ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      11/100         0G     0.1642         10        224: 100% ━━━━━━━━━━━━ 5/5 2.2s/it 10.8s2.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.0it/s 1.0s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      12/100         0G     0.1166         10        224: 100% ━━━━━━━━━━━━ 5/5 2.4s/it 12.0s2.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.1s/it 1.1s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      13/100         0G     0.1084         10        224: 100% ━━━━━━━━━━━━ 5/5 2.4s/it 11.8s1.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.1s/it 1.1s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      14/100         0G     0.1013         10        224: 100% ━━━━━━━━━━━━ 5/5 2.1s/it 10.6s2.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.2s/it 1.2s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      15/100         0G     0.1044         10        224: 100% ━━━━━━━━━━━━ 5/5 2.2s/it 11.2s2.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.0it/s 1.0s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      16/100         0G    0.07635         10        224: 100% ━━━━━━━━━━━━ 5/5 2.2s/it 11.2s2.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      17/100         0G     0.0646         10        224: 100% ━━━━━━━━━━━━ 5/5 2.0s/it 10.0s1.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.1s/it 1.1s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      18/100         0G     0.1112         10        224: 100% ━━━━━━━━━━━━ 5/5 1.9s/it 9.6s1.8ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.2it/s 0.8s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      19/100         0G     0.1538         10        224: 100% ━━━━━━━━━━━━ 5/5 1.7s/it 8.3s1.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.2it/s 0.8s
#                    all          1          1
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 9, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 19 epochs completed in 0.058 hours.
# Optimizer stripped from C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\exp4_img224_b32_lr0.0005_e100_Adam_pat104\weights\last.pt, 11.0MB
# Optimizer stripped from C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\exp4_img224_b32_lr0.0005_e100_Adam_pat104\weights\best.pt, 11.0MB
#
# Validating C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\exp4_img224_b32_lr0.0005_e100_Adam_pat104\weights\best.pt...
# Ultralytics 8.3.252  Python-3.13.5 torch-2.9.1+cpu CPU (Intel Core(TM) Ultra 7 165H)
# YOLO11s-cls summary (fused): 47 layers, 5,436,690 parameters, 0 gradients, 12.0 GFLOPs
# train: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\train... found 138 images in 2 classes
# val: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\val... found 29 images in 2 classes
# test: C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\dataset_cls\test... found 32 images in 2 classes
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.4it/s 0.7s
#                    all          1          1
# Speed: 0.0ms preprocess, 10.4ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to C:\Users\User\Documents\GitHub\grupo1reto2\Piezas\Clasificacion\runs_cls\exp4_img224_b32_lr0.0005_e100_Adam_pat104
#                                    exp_name  \
# 0   exp1_img224_b16_lr0.001_e100_Adam_pat10
# 3  exp4_img224_b32_lr0.0005_e100_Adam_pat10
# 1  exp2_img224_b16_lr0.0005_e100_Adam_pat10
# 2   exp3_img224_b32_lr0.001_e100_Adam_pat10
#
#                                              best_pt  imgsz  batch     lr0  \
# 0  C:\Users\User\Documents\GitHub\grupo1reto2\Pie...    224     16  0.0010
# 3  C:\Users\User\Documents\GitHub\grupo1reto2\Pie...    224     32  0.0005
# 1  C:\Users\User\Documents\GitHub\grupo1reto2\Pie...    224     16  0.0005
# 2  C:\Users\User\Documents\GitHub\grupo1reto2\Pie...    224     32  0.0010
#
#    epochs_max  patience  accuracy  precision_defecto  recall_defecto  \
# 0         100        10   0.96875                1.0             0.8
# 3         100        10   0.96875                1.0             0.8
# 1         100        10   0.93750                1.0             0.6
# 2         100        10   0.93750                1.0             0.6
#
#    f1_defecto
# 0    0.888889
# 3    0.888889
# 1    0.750000
# 2    0.750000
# Guardado: grid_results.csv

# %% [markdown]
# # Gráficas para comparar y elegir

# %%
# %matplotlib inline
plt.figure(figsize=(10,4))
df_sorted = df_grid.sort_values(SELECT_BY, ascending=False)
plt.bar(df_sorted["exp_name"], df_sorted[SELECT_BY])
plt.xticks(rotation=60, ha="right")
plt.title(f"Experimentos ordenados por {SELECT_BY}")
plt.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.show()

plt.figure(figsize=(6,4))
plt.scatter(df_grid["accuracy"], df_grid["recall_defecto"])
for _, r in df_grid.iterrows():
    plt.text(r["accuracy"], r["recall_defecto"], r["exp_name"], fontsize=8)
plt.xlabel("Accuracy")
plt.ylabel("Recall(defecto)")
plt.title("Accuracy vs Recall(defecto)")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# Dado que varios experimentos alcanzaron métricas idénticas en términos de accuracy, recall y F1-score para la clase defecto, se seleccionó el experimento exp2 por presentar una tasa de aprendizaje más conservadora y un tamaño de batch moderado, lo que favorece una mayor estabilidad del entrenamiento y un menor riesgo de sobreajuste.

# %%
FINAL_MODEL_PATH = "runs_cls/exp2_img224_b16_lr0.0005_e100_Adam_pat10/weights/best.pt"

# %%
# Errores que se le escapan al mejor modelo:

df_errors = df_test[
    (df_test["true_class"] == "defecto") &
    (df_test["pred_class"] == "no_defecto")
].sort_values("confidence", ascending=False)

display(df_errors.head(10))
# Out:
#                                  image_path            image true_class  \
# 2  dataset_cls\test\defecto\kos14_Part7.jpg  kos14_Part7.jpg    defecto
#
#    pred_class  confidence
# 2  no_defecto     0.99976
