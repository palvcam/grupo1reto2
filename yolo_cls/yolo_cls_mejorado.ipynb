# %% [markdown]
# # Librerías

# %%
from pathlib import Path
import random
import shutil
from ultralytics import YOLO
import numpy as np

# %% [markdown]
# # Rutas

# %%
# Directorio del notebook
PATH = Path(".")  # "." apunta a la carpeta actual donde estás ejecutando el notebook

# Dataset externo
DATASET_PATH = Path("../dataset_cls")  # ajusta según dónde esté tu carpeta

# Directorio de test
TEST_DIR = DATASET_PATH / "test"

# %% [markdown]
# # Modelo

# %%
model = YOLO("yolo11s-cls.pt")

# %%
model.train(
    data=DATASET_PATH,
    epochs=50,
    imgsz=224,
    batch=32,
    patience=10,
    optimizer="Adam",
    lr0=1e-3,
    verbose=True
)
# Out:
# Ultralytics 8.3.252  Python-3.13.5 torch-2.9.1+cpu CPU (Intel Core(TM) Ultra 7 165H)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=..\dataset_cls, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=Adam, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\runs\classify\train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: C:\Users\User\Documents\GitHub\grupo1reto2\dataset_cls\train... found 290 images in 2 classes
# val: C:\Users\User\Documents\GitHub\grupo1reto2\dataset_cls\val... found 62 images in 2 classes
# test: C:\Users\User\Documents\GitHub\grupo1reto2\dataset_cls\test... found 63 images in 2 classes
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  10                  -1  1    660482  ultralytics.nn.modules.head.Classify         [512, 2]
# YOLO11s-cls summary: 86 layers, 5,445,570 parameters, 5,445,570 gradients, 12.1 GFLOPs
# Transferred 234/236 items from pretrained weights
# train: Fast image access  (ping: 0.00.0 ms, read: 624.6122.3 MB/s, size: 237.8 KB)
# train: Scanning C:\Users\User\Documents\GitHub\grupo1reto2\dataset_cls\train... 290 images, 0 corrupt: 100% ━━━━━━━━━━━━ 290/290 32.0Mit/s 0.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 833.7298.5 MB/s, size: 252.8 KB)
# val: Scanning C:\Users\User\Documents\GitHub\grupo1reto2\dataset_cls\val... 62 images, 0 corrupt: 100% ━━━━━━━━━━━━ 62/62 5.9Mit/s 0.0s
# optimizer: Adam(lr=0.001, momentum=0.937) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 0 dataloader workers
# Logging results to C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\runs\classify\train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/50         0G     0.6112          2        224: 100% ━━━━━━━━━━━━ 10/10 1.7s/it 17.0s.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.9s/it 1.9s
#                    all      0.855          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/50         0G     0.2447          2        224: 100% ━━━━━━━━━━━━ 10/10 1.7s/it 17.0s.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.5s/it 1.5s
#                    all      0.952          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/50         0G     0.2242          2        224: 100% ━━━━━━━━━━━━ 10/10 1.7s/it 17.0s.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6s/it 1.6s
#                    all      0.968          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/50         0G     0.2064          2        224: 100% ━━━━━━━━━━━━ 10/10 1.7s/it 16.8s.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6s/it 1.6s
#                    all      0.968          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/50         0G        0.2          2        224: 100% ━━━━━━━━━━━━ 10/10 1.7s/it 17.0s.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6s/it 1.6s
#                    all      0.984          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/50         0G     0.1227          2        224: 100% ━━━━━━━━━━━━ 10/10 1.6s/it 16.5s.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6s/it 1.6s
#                    all      0.984          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/50         0G     0.1235          2        224: 100% ━━━━━━━━━━━━ 10/10 1.6s/it 16.4s.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6s/it 1.6s
#                    all      0.968          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/50         0G     0.1199          2        224: 100% ━━━━━━━━━━━━ 10/10 2.4s/it 24.2s.7ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6s/it 1.6s
#                    all      0.968          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/50         0G     0.1082          2        224: 100% ━━━━━━━━━━━━ 10/10 1.6s/it 15.9s.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6s/it 1.6s
#                    all      0.984          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/50         0G     0.1461          2        224: 100% ━━━━━━━━━━━━ 10/10 1.6s/it 16.1s.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6s/it 1.6s
#                    all      0.984          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/50         0G     0.1783          2        224: 100% ━━━━━━━━━━━━ 10/10 1.7s/it 17.5s.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6s/it 1.6s
#                    all      0.694          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/50         0G     0.1149          2        224: 100% ━━━━━━━━━━━━ 10/10 1.7s/it 17.0s.7ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6s/it 1.6s
#                    all      0.984          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/50         0G     0.1052          2        224: 100% ━━━━━━━━━━━━ 10/10 1.6s/it 16.4s.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6s/it 1.6s
#                    all      0.968          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/50         0G     0.1238          2        224: 100% ━━━━━━━━━━━━ 10/10 1.7s/it 17.0s.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6s/it 1.6s
#                    all      0.984          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/50         0G     0.2234          2        224: 100% ━━━━━━━━━━━━ 10/10 1.7s/it 16.9s.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6s/it 1.6s
#                    all      0.984          1
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 5, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 15 epochs completed in 0.080 hours.
# Optimizer stripped from C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\runs\classify\train\weights\last.pt, 11.0MB
# Optimizer stripped from C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\runs\classify\train\weights\best.pt, 11.0MB
#
# Validating C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\runs\classify\train\weights\best.pt...
# Ultralytics 8.3.252  Python-3.13.5 torch-2.9.1+cpu CPU (Intel Core(TM) Ultra 7 165H)
# YOLO11s-cls summary (fused): 47 layers, 5,436,690 parameters, 0 gradients, 12.0 GFLOPs
# train: C:\Users\User\Documents\GitHub\grupo1reto2\dataset_cls\train... found 290 images in 2 classes
# val: C:\Users\User\Documents\GitHub\grupo1reto2\dataset_cls\val... found 62 images in 2 classes
# test: C:\Users\User\Documents\GitHub\grupo1reto2\dataset_cls\test... found 63 images in 2 classes
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1/1 1.6s/it 1.6s
#                    all      0.984          1
# Speed: 0.0ms preprocess, 10.8ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\runs\classify\train
# ultralytics.utils.metrics.ClassifyMetrics object with attributes:
#
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x000001D7589EE390>
# curves: []
# curves_results: []
# fitness: 0.9919354915618896
# keys: ['metrics/accuracy_top1', 'metrics/accuracy_top5']
# results_dict: {'metrics/accuracy_top1': 0.9838709831237793, 'metrics/accuracy_top5': 1.0, 'fitness': 0.9919354915618896}
# save_dir: WindowsPath('C:/Users/User/Documents/GitHub/grupo1reto2/yolo_cls/runs/classify/train')
# speed: {'preprocess': 0.00069677198846494, 'inference': 10.775338708152693, 'loss': 3.8709972173936905e-05, 'postprocess': 9.032326840585278e-05}
# task: 'classify'
# top1: 0.9838709831237793
# top5: 1.0

# %% [markdown]
# # Evaluación

# %%
TEST_DIR = DATASET_PATH / "test"

MODEL_PATH = PATH / "../yolo_cls/runs/classify/train/weights/best.pt"
model = YOLO(MODEL_PATH)

# %%
results = []
for cls_dir in TEST_DIR.iterdir():
    if cls_dir.is_dir():
        print(f"Procesando carpeta: {cls_dir.name}")
        results.extend(model(cls_dir))
# Out:
# Procesando carpeta: defecto
#
# image 1/9 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\defecto\Part4.jpg: 224x224 defecto 1.00, no_defecto 0.00, 44.8ms
# image 2/9 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\defecto\kos02_Part6.jpg: 224x224 defecto 0.99, no_defecto 0.01, 19.7ms
# image 3/9 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\defecto\kos08_Part2.jpg: 224x224 no_defecto 1.00, defecto 0.00, 24.5ms
# image 4/9 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\defecto\kos09_Part6.jpg: 224x224 defecto 1.00, no_defecto 0.00, 21.9ms
# image 5/9 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\defecto\kos15_Part3.jpg: 224x224 no_defecto 0.96, defecto 0.04, 23.9ms
# image 6/9 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\defecto\kos16_Part5.jpg: 224x224 defecto 1.00, no_defecto 0.00, 29.3ms
# image 7/9 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\defecto\kos18_Part3.jpg: 224x224 defecto 1.00, no_defecto 0.00, 19.1ms
# image 8/9 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\defecto\kos39_Part7.jpg: 224x224 defecto 1.00, no_defecto 0.00, 25.1ms
# image 9/9 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\defecto\kos46_Part7.jpg: 224x224 defecto 1.00, no_defecto 0.00, 25.5ms
# Speed: 9.5ms preprocess, 26.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Procesando carpeta: no_defecto
#
# image 1/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\Part0.jpg: 224x224 no_defecto 1.00, defecto 0.00, 26.6ms
# image 2/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos03_Part3.jpg: 224x224 no_defecto 1.00, defecto 0.00, 24.5ms
# image 3/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos04_Part2.jpg: 224x224 no_defecto 1.00, defecto 0.00, 27.0ms
# image 4/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos05_Part0.jpg: 224x224 no_defecto 1.00, defecto 0.00, 27.6ms
# image 5/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos05_Part6.jpg: 224x224 no_defecto 1.00, defecto 0.00, 28.7ms
# image 6/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos06_Part0.jpg: 224x224 no_defecto 1.00, defecto 0.00, 25.9ms
# image 7/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos06_Part1.jpg: 224x224 no_defecto 1.00, defecto 0.00, 30.9ms
# image 8/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos06_Part5.jpg: 224x224 no_defecto 1.00, defecto 0.00, 18.5ms
# image 9/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos08_Part3.jpg: 224x224 no_defecto 1.00, defecto 0.00, 24.3ms
# image 10/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos11_Part1.jpg: 224x224 no_defecto 1.00, defecto 0.00, 23.9ms
# image 11/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos11_Part3.jpg: 224x224 no_defecto 1.00, defecto 0.00, 28.4ms
# image 12/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos12_Part7.jpg: 224x224 no_defecto 1.00, defecto 0.00, 27.1ms
# image 13/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos13_Part4.jpg: 224x224 no_defecto 1.00, defecto 0.00, 25.6ms
# image 14/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos15_Part0.jpg: 224x224 no_defecto 1.00, defecto 0.00, 26.7ms
# image 15/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos16_Part2.jpg: 224x224 no_defecto 1.00, defecto 0.00, 26.4ms
# image 16/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos16_Part3.jpg: 224x224 no_defecto 1.00, defecto 0.00, 24.3ms
# image 17/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos17_Part0.jpg: 224x224 no_defecto 1.00, defecto 0.00, 25.9ms
# image 18/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos17_Part4.jpg: 224x224 no_defecto 1.00, defecto 0.00, 22.8ms
# image 19/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos17_Part6.jpg: 224x224 no_defecto 1.00, defecto 0.00, 23.5ms
# image 20/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos18_Part0.jpg: 224x224 no_defecto 1.00, defecto 0.00, 19.1ms
# image 21/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos18_Part7.jpg: 224x224 no_defecto 1.00, defecto 0.00, 24.5ms
# image 22/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos20_Part2.jpg: 224x224 no_defecto 1.00, defecto 0.00, 24.0ms
# image 23/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos20_Part3.jpg: 224x224 no_defecto 1.00, defecto 0.00, 28.0ms
# image 24/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos20_Part5.jpg: 224x224 no_defecto 1.00, defecto 0.00, 23.0ms
# image 25/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos20_Part6.jpg: 224x224 no_defecto 1.00, defecto 0.00, 22.9ms
# image 26/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos21_Part2.jpg: 224x224 no_defecto 1.00, defecto 0.00, 25.4ms
# image 27/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos22_Part2.jpg: 224x224 no_defecto 1.00, defecto 0.00, 27.4ms
# image 28/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos24_Part2.jpg: 224x224 no_defecto 1.00, defecto 0.00, 22.2ms
# image 29/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos24_Part7.jpg: 224x224 no_defecto 1.00, defecto 0.00, 23.2ms
# image 30/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos27_Part1.jpg: 224x224 no_defecto 1.00, defecto 0.00, 21.0ms
# image 31/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos27_Part5.jpg: 224x224 no_defecto 1.00, defecto 0.00, 28.7ms
# image 32/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos27_Part6.jpg: 224x224 no_defecto 1.00, defecto 0.00, 31.9ms
# image 33/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos28_Part1.jpg: 224x224 no_defecto 1.00, defecto 0.00, 26.7ms
# image 34/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos28_Part7.jpg: 224x224 no_defecto 1.00, defecto 0.00, 24.2ms
# image 35/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos30_Part1.jpg: 224x224 no_defecto 1.00, defecto 0.00, 25.9ms
# image 36/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos30_Part4.jpg: 224x224 no_defecto 1.00, defecto 0.00, 24.6ms
# image 37/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos34_Part3.jpg: 224x224 no_defecto 1.00, defecto 0.00, 25.9ms
# image 38/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos34_Part5.jpg: 224x224 no_defecto 1.00, defecto 0.00, 25.2ms
# image 39/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos34_Part7.jpg: 224x224 no_defecto 1.00, defecto 0.00, 27.9ms
# image 40/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos37_Part5.jpg: 224x224 no_defecto 1.00, defecto 0.00, 17.2ms
# image 41/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos40_Part3.jpg: 224x224 no_defecto 1.00, defecto 0.00, 27.7ms
# image 42/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos42_Part1.jpg: 224x224 no_defecto 1.00, defecto 0.00, 22.3ms
# image 43/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos42_Part7.jpg: 224x224 no_defecto 1.00, defecto 0.00, 24.0ms
# image 44/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos43_Part5.jpg: 224x224 no_defecto 1.00, defecto 0.00, 21.3ms
# image 45/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos45_Part6.jpg: 224x224 no_defecto 1.00, defecto 0.00, 29.3ms
# image 46/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos45_Part7.jpg: 224x224 no_defecto 1.00, defecto 0.00, 28.5ms
# image 47/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos46_Part2.jpg: 224x224 no_defecto 1.00, defecto 0.00, 26.2ms
# image 48/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos46_Part4.jpg: 224x224 no_defecto 1.00, defecto 0.00, 23.6ms
# image 49/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos47_Part3.jpg: 224x224 no_defecto 1.00, defecto 0.00, 24.6ms
# image 50/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos47_Part7.jpg: 224x224 no_defecto 1.00, defecto 0.00, 22.3ms
# image 51/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos48_Part6.jpg: 224x224 no_defecto 1.00, defecto 0.00, 28.0ms
# image 52/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos49_Part4.jpg: 224x224 no_defecto 1.00, defecto 0.00, 25.3ms
# image 53/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos49_Part6.jpg: 224x224 no_defecto 1.00, defecto 0.00, 28.6ms
# image 54/54 C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos50_Part1.jpg: 224x224 no_defecto 1.00, defecto 0.00, 19.3ms
# Speed: 9.4ms preprocess, 25.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)

# %%
# Predicciones
for r in results:
    probs = r.probs.data.cpu().numpy()
    names_dict = r.names

    pred_class_id = np.argmax(probs)
    pred_class_name = names_dict[pred_class_id]
    confidence = probs[pred_class_id]

    print(f"{r.path} → {pred_class_name} ({confidence:.4f})")
# Out:
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\defecto\Part4.jpg → defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\defecto\kos02_Part6.jpg → defecto (0.9891)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\defecto\kos08_Part2.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\defecto\kos09_Part6.jpg → defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\defecto\kos15_Part3.jpg → no_defecto (0.9630)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\defecto\kos16_Part5.jpg → defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\defecto\kos18_Part3.jpg → defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\defecto\kos39_Part7.jpg → defecto (0.9999)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\defecto\kos46_Part7.jpg → defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\Part0.jpg → no_defecto (0.9999)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos03_Part3.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos04_Part2.jpg → no_defecto (0.9999)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos05_Part0.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos05_Part6.jpg → no_defecto (0.9999)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos06_Part0.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos06_Part1.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos06_Part5.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos08_Part3.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos11_Part1.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos11_Part3.jpg → no_defecto (0.9999)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos12_Part7.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos13_Part4.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos15_Part0.jpg → no_defecto (0.9994)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos16_Part2.jpg → no_defecto (0.9999)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos16_Part3.jpg → no_defecto (0.9998)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos17_Part0.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos17_Part4.jpg → no_defecto (0.9998)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos17_Part6.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos18_Part0.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos18_Part7.jpg → no_defecto (0.9999)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos20_Part2.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos20_Part3.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos20_Part5.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos20_Part6.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos21_Part2.jpg → no_defecto (0.9998)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos22_Part2.jpg → no_defecto (0.9998)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos24_Part2.jpg → no_defecto (0.9982)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos24_Part7.jpg → no_defecto (0.9998)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos27_Part1.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos27_Part5.jpg → no_defecto (0.9999)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos27_Part6.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos28_Part1.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos28_Part7.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos30_Part1.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos30_Part4.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos34_Part3.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos34_Part5.jpg → no_defecto (0.9999)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos34_Part7.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos37_Part5.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos40_Part3.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos42_Part1.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos42_Part7.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos43_Part5.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos45_Part6.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos45_Part7.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos46_Part2.jpg → no_defecto (0.9993)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos46_Part4.jpg → no_defecto (0.9953)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos47_Part3.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos47_Part7.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos48_Part6.jpg → no_defecto (1.0000)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos49_Part4.jpg → no_defecto (0.9989)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos49_Part6.jpg → no_defecto (0.9996)
# C:\Users\User\Documents\GitHub\grupo1reto2\yolo_cls\..\dataset_cls\test\no_defecto\kos50_Part1.jpg → no_defecto (0.9997)

# %%
correct = 0
total = 0
for r in results:
    probs = r.probs.data.cpu().numpy()
    pred_class = r.names[np.argmax(probs)]
    true_class = Path(r.path).parent.name

    if pred_class == true_class:
        correct += 1
    total += 1

accuracy = correct / total if total > 0 else 0.0
print("\n--- RESULTADOS FINALES ---")
print(f"Total imágenes test: {total}")
print(f"Correctas: {correct}")
print(f"Accuracy test: {accuracy:.4f}")
# Out:
# --- RESULTADOS FINALES ---
# Total imágenes test: 63
# Correctas: 61
# Accuracy test: 0.9683
